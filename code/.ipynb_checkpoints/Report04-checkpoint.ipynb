# %% [markdown]
# # Report 04
# ### Yuzhong Huang

# %%
# imports tools for solving bayes problems

from __future__ import print_function, division

import numpy as np
import math

import thinkbayes2
from thinkbayes2 import Pmf, Cdf, Suite, Joint
import thinkplot

% matplotlib inline

# %% [markdown]
# ## The World Cup Problem from ThinkBayes

# %% [markdown]
# In the 2014 FIFA World Cup, Germany played Brazil in a semifinal match. Germany scored after 11 minutes and again at the 23 minute mark. At that point in the match, how many goals would you expect Germany to score after 90 minutes? What was the probability that they would score 5 more goals (as, in fact, they did)?

# %% [markdown]
# My solution follows

# %% [markdown]
# I'll use λ to represent the goal-scoring rate for Germany. To compute prior probabilities for values of λ, we'll use a Gamma distribution. And suppose average score in a game is around 1.5

# %%
from scipy.special import gamma 

def EvalGammaPdf(lam, a):
    """Computes the Gamma PDF.

    lam: lambda
    a: parameter of the gamma distribution
    """
    return lam**(a-1) * math.exp(-lam) / gamma(a)

# %%
def MakeGammaPmf(lams, a):
    """Takes a list of hypothetical rates and returns a Pmf object.

    lams: a set of possible lambdas
    a: parameter of the gamma distribution
    """
    pmf = Pmf()
    for lam in lams:
        pmf[lam] = EvalGammaPdf(lam, a)
        
    pmf.Normalize()
    return pmf

# %% [markdown]
# Then we will pick a set of lambdas and then plot a pdf to visualize the hypothetical probablity of goals per game. Let's assume a prior to be 1.5 goals per game.

# %%
lambdas = np.linspace(0, 8, 101)
pmf = MakeGammaPmf(lambdas, 1.5)
thinkplot.Pdf(pmf)
thinkplot.Config(xlabel='Goals per game')
pmf.Mean()
# Out:
# /home/yuzhong/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.py:519: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
# 1.499536574353068

# %% [markdown]
# Next, we will initialize a soccer class to represents a soccer team's goal in a game

# %%
class Soccer(Suite):
    """soccer team's goal in a game"""

    def Likelihood(self, data, hypo):
        """Computes the likelihood of the data under the hypothesis.

        hypo: hypothetical lambda value
        data: interarrival time between goals in minutes
        """
        # get the time ratio
        x = data / 90
        like = hypo * math.exp(-hypo * x)
        return like

# %%
# initialize with the prior
soccer = Soccer(pmf)
thinkplot.Pdf(soccer, color='0.8')
# update with the first goal
soccer.Update(11)
thinkplot.Pdf(soccer, color='0.5')
# update with the second goal
soccer.Update(23-11)
thinkplot.Pdf(soccer)

thinkplot.Config(xlabel='Goals per game')
soccer.Mean()
# Out:
# 2.7550973121762756

# %% [markdown]
# As we can see, how does the distribution changes as we updated with the goals. The distribution shifted to the right, give more probablity to more goals. And the average value is 2.76 after the updates. Now, we can make a cdf from the soccer object. The chance that the game will have 5 or more goals can be computed as 1 - cdf[5].

# %%
# make cdf from the soccer object
cdf = soccer.MakeCdf()
p = 1 - cdf[5]
print(p)
# Out:
# 0.0789271378526

# %% [markdown]
# Therefore, at the point that Germany scored 2 goals, according to our model, the average goal of the game is 2.76. And the chance that Germany will score 5 or more goals is around 0.07

# %% [markdown]
# ## Original Problem

# %% [markdown]
# Suppose there is a restaurant that you often go during weekends. You have tried three dishes in the restaurant. You have tried the first dish 5 times, the second dish 7 times and 4 times for the third dish. For the first dish, you figured that there are 3 styles; 2 styles for the second dish; 3 styles for the third dish. Assumed that unique styles comes from unique cooks. Guess how many cooks are there in the restaurant

# %% [markdown]
# #### My solution follows.
#
# In my solution, I will write a class to represent the restaurant and initialize with a set of hypothesis. But before that, we need to solve the problem of the probablity of getting k unique objects from c choices out of n total objects.

# %%
def choice(total, choices, unique):
    """
    Choice returns the probablity of getting 'unique' numbers of different objects 
    from 'choices' numbers of choices out of 'total' number of objects
    """
    return math.factorial(total-1) / math.factorial(total-unique) * math.pow(unique, choices - unique) / math.pow(total, choices - 1)

# %%
class Restaurant(Suite):
    """represents the restaurant that we are guessing"""

    def Likelihood(self, data, hypo):
        """Computes the likelihood of the data under the hypothesis.

        hypo: hypothetical lambda value
        data: interarrival time between goals in minutes
        """
        styles, times = data
        if hypo > styles:
            like = choice(hypo, times, styles)
        else:
            like = 0
            
        return like

# %%
# initial prior assume that it's equally likely that there are 0 to 20 cooks in the restaurant.
pmf = Pmf(range(20))
r = Restaurant(pmf)

# %%
# update with the first dish
r.Update((3, 5))
thinkplot.Pdf(r)

# %%
# update with the second dish
r.Update((2, 7))
thinkplot.Pdf(r)

# %%
# update with the third dish
r.Update((3, 4))
thinkplot.Pdf(r)

# %% [markdown]
# As we can see, after the update of three dishes, we have a relatively high probablity that there are 4 cooks in this restaurant
